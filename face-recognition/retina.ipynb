# %%
import sys
import tensorflow as tf
import matplotlib.pyplot as plt
from retinaface import RetinaFace
import numpy as np
import cv2
print(sys.version)
print(np.__version__)
print(tf.__version__)
# Out:
# 3.10.15 | packaged by Anaconda, Inc. | (main, Oct  3 2024, 07:22:19) [MSC v.1929 64 bit (AMD64)]
# 1.26.4
# 2.10.1

# %%
imgpath:str = './data/scarlett-johansson/test/img-16.png'
image = cv2.imread(imgpath)
img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) #Convertir BGR a RGB para matplotlib

plt.figure(figsize=(16,16))
plt.subplot(1, 2, 1)
plt.imshow(img_rgb)
plt.title('Image')
plt.axis('on')

#detectar los rostros usando RetinaFace
faces = RetinaFace.detect_faces(imgpath)

#print(len(faces.keys()))
for key in faces.keys():
    face = faces[key]
    facialarea = face["facial_area"]
    cv2.rectangle(image, (facialarea[2],facialarea[3]), (facialarea[0],facialarea[1]), (220, 155, 0), 2)

# Convertir la imagen con las cajas delimitadoras a RGB para mostrarla con matplotlib
img_rgb_with_boxes = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Mostrar la imagen con los rostros detectados
plt.figure(figsize=(16,16))
plt.subplot(1, 2, 2)
plt.imshow(img_rgb_with_boxes)
plt.title('Face detection RetinaFace')
plt.axis('on')
plt.show()
